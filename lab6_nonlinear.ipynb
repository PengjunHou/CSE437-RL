# %% [markdown]
# <a href="https://colab.research.google.com/github/PengjunHou/CSE437-RL/blob/main/lab6_nonlinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 6: Non-linear function approximation
#
# ## Exercise 1: Q-Learning with a Neural Network (PyTorch) on MountainCar
#
# **Objective:**
# Implement **Q-learning** with a **PyTorch neural network** to solve `MountainCar-v0`. You will approximate Q(s, a) with a small MLP, train it from batches of transitions sampled from a replay buffer, and evaluate the learned policy.
#
# ---
#
# ## Environment
# - **Gym** environment: `MountainCar-v0`
# - **State**: continuous (position, velocity) → shape `(2,)`
# - **Actions**: {0: left, 1: no push, 2: right}
# - **Reward**: -1 per step until the goal (`position >= 0.5`)
# - **Episode limit**: 500 steps
# - **Goal**: reduce steps-to-goal and improve return over training
#
# ---
#
# ## What You Must Implement
#
# ### 1) Q-Network (PyTorch)
# Create a small MLP `QNetwork` that maps `state -> Q-values for 3 actions`.
# - Inputs: `(batch_size, 2)` float32
# - Outputs: `(batch_size, 3)` Q-values
# - Suggested architecture: `2 → 64 → 3` with ReLU
# - Initialize weights reasonably (PyTorch defaults are fine)
#
# ### 2) Replay Buffer
# A cyclic buffer to store transitions `(s, a, r, s_next, done)`:
# - `append(s, a, r, s_next, done)`
# - `sample(batch_size)` → tensors ready for PyTorch (float32 for states, int64 for actions, float32 for rewards/done)
#
# ### 3) ε-Greedy Policy
# - With probability `epsilon`: pick a random action
# - Otherwise: `argmax_a Q(s, a)` from the current network
# - Use **decaying ε** (e.g., from 1.0 down to 0.05 over ~20–50k steps)
#
# ### 4) Q-Learning Target and Loss
# For a sampled batch:
# - Compute `q_pred = Q(s).gather(1, a)`  (shape `(batch, 1)`)
# - Compute target:
#   - If `done`: `target = r`
#   - Else: `target = r + gamma * max_a' Q(s_next, a').detach()`
# - Loss: Mean Squared Error (MSE) between `q_pred` and `target`
#
# > **Stabilization (recommended)**: Use a **target network** `Q_target` (periodically copy weights from `Q_online`) to compute the max over next-state actions. Update every `target_update_freq` steps.
#
# ### 5) Deep Q-learning method
# - For each environment step:
#   1. Select action with ε-greedy
#   2. Step the env, store transition in buffer
#   3. If `len(buffer) >= batch_size`:
#      - Sample a batch
#      - Compute `q_pred`, `target`
#      - Backprop: `optimizer.zero_grad(); loss.backward(); optimizer.step()`
#      - (Optional) gradient clipping (e.g., `clip_grad_norm_` at 10)
#   4. Periodically update `Q_target ← Q_online` (if using target net)
# - Track episode returns (sum of rewards) and steps-to-goal
#
# ---
#
# ## Evaluation
# - Run **evaluation episodes** with `epsilon = 0.0` (greedy) every N training episodes
# - Report:
#   - Average steps-to-goal (lower is better; random policy is ~200)
#   - Average return (less negative is better)
# - Plot:
#   - Training episode return
#
# ---
#
# ## Deliverables
# 1. **Code**: In a notebook.
# 2. **Plots**:
#    - Episode  vs return
#    - Final value function (State (postition and velocity) Vs Max(Q(state)))
#
# 3. **Short write-up** (also in the notebook):
#    - **Performance of your DQN agent**: How quickly does it learn? Does it reach the goal consistently?
#    - **Comparison with tile coding**:
#      - Which representation learns faster?
#      - Which one is more stable?
#      - How do the function approximation choices (linear with tiles vs. neural network) affect generalization?
#      - Did the NN require more tuning (learning rate, ε schedule) compared to tile coding?
#    - **Insights**: What are the trade-offs between hand-crafted features (tiles) and learned features (neural networks)?

# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# Set up environment
env = gym.make("MountainCar-v0")
n_actions = env.action_space.n
state_dim = env.observation_space.shape[0]

# Hyperparameters
gamma = 0.99
alpha = 0.001
epsilon = 1.0
epsilon_min = 0.01
epsilon_decay = 0.995
num_episodes = 5000
batch_size = 64
replay_buffer_size = 50000

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define Q-Network
class QNetwork(nn.Module):
    def __init__(self, state_dim, n_actions):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, n_actions)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %%
# Initialize Q-network and optimizer
q_net = QNetwork(state_dim, n_actions).to(device)
optimizer = optim.Adam(q_net.parameters(), lr=alpha)
loss_fn = nn.MSELoss()
replay_buffer = deque(maxlen=replay_buffer_size)

# %%
def epsilon_greedy(state, epsilon):
  ############ TODO ###########
  rand_v = np.random.rand()
  if rand_v < epsilon:
    return env.action_space.sample()
  else:
    s = torch.FloatTensor(state).to(device)
    return q_net(s).max(0)[1].item()

# %%
def train_dqn():
    """Train the DQN using experience replay."""
    if len(replay_buffer) < batch_size:
        return
    batch = random.sample(replay_buffer, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(states).to(device)
    actions = torch.LongTensor(actions).to(device)
    rewards = torch.FloatTensor(rewards).to(device)
    next_states = torch.FloatTensor(next_states).to(device)
    dones = torch.FloatTensor(dones).to(device)

    q_values = q_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
    next_q_values = q_net(next_states).max(1)[0].detach()
    targets = rewards + gamma * next_q_values * (1 - dones)

    loss = loss_fn(q_values, targets)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
## MAIN Loop ###
rewards_dqn = []

for episode in range(num_episodes):
  state = env.reset()[0]
  total_reward = 0
  done = False

  while not done:
    action = epsilon_greedy(state, epsilon)
    next_state, reward, done, _, _ = env.step(action)
    ############ TODO ###########
    total_reward += reward
    replay_buffer.append((state, action, reward, next_state, done))
    state = next_state
    if len(replay_buffer) >= batch_size:
      train_dqn()
  epsilon *= epsilon_decay
  rewards_dqn.append(total_reward)
  print(f"Episode {episode+1}/{num_episodes}, reward={total_reward:.2f}, epsilon={epsilon:.3f}")
# Out:
# Episode 1/5000, reward=-7390.00, epsilon=0.995
# Episode 2/5000, reward=-148247.00, epsilon=0.990
# Episode 3/5000, reward=-53500.00, epsilon=0.985
# Episode 4/5000, reward=-9638.00, epsilon=0.980
# Episode 5/5000, reward=-36843.00, epsilon=0.975
# Episode 6/5000, reward=-4170.00, epsilon=0.970
# Episode 7/5000, reward=-7785.00, epsilon=0.966
# Episode 8/5000, reward=-4481.00, epsilon=0.961
# Episode 9/5000, reward=-39830.00, epsilon=0.956
# Episode 10/5000, reward=-14706.00, epsilon=0.951
# Episode 11/5000, reward=-2970.00, epsilon=0.946
# Episode 12/5000, reward=-8903.00, epsilon=0.942
# Episode 13/5000, reward=-14221.00, epsilon=0.937
# Episode 14/5000, reward=-17556.00, epsilon=0.932
# Episode 15/5000, reward=-22014.00, epsilon=0.928
# Episode 16/5000, reward=-4064.00, epsilon=0.923
# Episode 17/5000, reward=-14477.00, epsilon=0.918
# Episode 18/5000, reward=-4346.00, epsilon=0.914
# Episode 19/5000, reward=-7540.00, epsilon=0.909
# Episode 20/5000, reward=-8867.00, epsilon=0.905
# Episode 21/5000, reward=-4728.00, epsilon=0.900
# Episode 22/5000, reward=-1862.00, epsilon=0.896
# Episode 23/5000, reward=-3482.00, epsilon=0.891
# Episode 24/5000, reward=-2249.00, epsilon=0.887
# Episode 25/5000, reward=-12238.00, epsilon=0.882
# Episode 26/5000, reward=-1846.00, epsilon=0.878
# Episode 27/5000, reward=-1337.00, epsilon=0.873
# Episode 28/5000, reward=-1408.00, epsilon=0.869
# Episode 29/5000, reward=-1942.00, epsilon=0.865
# Episode 30/5000, reward=-2122.00, epsilon=0.860
# Episode 31/5000, reward=-2333.00, epsilon=0.856
# Episode 32/5000, reward=-1560.00, epsilon=0.852
# Episode 33/5000, reward=-2090.00, epsilon=0.848
# Episode 34/5000, reward=-966.00, epsilon=0.843
# Episode 35/5000, reward=-1585.00, epsilon=0.839
# Episode 36/5000, reward=-387.00, epsilon=0.835
# Episode 37/5000, reward=-835.00, epsilon=0.831
# Episode 38/5000, reward=-933.00, epsilon=0.827
# Episode 39/5000, reward=-737.00, epsilon=0.822
# Episode 40/5000, reward=-506.00, epsilon=0.818
# Episode 41/5000, reward=-555.00, epsilon=0.814
# Episode 42/5000, reward=-563.00, epsilon=0.810
# Episode 43/5000, reward=-1398.00, epsilon=0.806
# Episode 44/5000, reward=-645.00, epsilon=0.802
# Episode 45/5000, reward=-1983.00, epsilon=0.798
# Episode 46/5000, reward=-1333.00, epsilon=0.794
# Episode 47/5000, reward=-404.00, epsilon=0.790
# Episode 48/5000, reward=-774.00, epsilon=0.786
# Episode 49/5000, reward=-851.00, epsilon=0.782
# Episode 50/5000, reward=-553.00, epsilon=0.778
# Episode 51/5000, reward=-892.00, epsilon=0.774
# Episode 52/5000, reward=-695.00, epsilon=0.771
# Episode 53/5000, reward=-551.00, epsilon=0.767
# Episode 54/5000, reward=-547.00, epsilon=0.763
# Episode 55/5000, reward=-1162.00, epsilon=0.759
# Episode 56/5000, reward=-526.00, epsilon=0.755
# Episode 57/5000, reward=-639.00, epsilon=0.751
# Episode 58/5000, reward=-891.00, epsilon=0.748
# Episode 59/5000, reward=-400.00, epsilon=0.744
# Episode 60/5000, reward=-322.00, epsilon=0.740
# Episode 61/5000, reward=-405.00, epsilon=0.737
# Episode 62/5000, reward=-475.00, epsilon=0.733
# Episode 63/5000, reward=-592.00, epsilon=0.729
# Episode 64/5000, reward=-405.00, epsilon=0.726
# Episode 65/5000, reward=-332.00, epsilon=0.722
# Episode 66/5000, reward=-403.00, epsilon=0.718
# Episode 67/5000, reward=-577.00, epsilon=0.715
# Episode 68/5000, reward=-349.00, epsilon=0.711
# Episode 69/5000, reward=-384.00, epsilon=0.708
# Episode 70/5000, reward=-350.00, epsilon=0.704
# Episode 71/5000, reward=-605.00, epsilon=0.701
# Episode 72/5000, reward=-278.00, epsilon=0.697
# Episode 73/5000, reward=-597.00, epsilon=0.694
# Episode 74/5000, reward=-433.00, epsilon=0.690
# Episode 75/5000, reward=-634.00, epsilon=0.687
# Episode 76/5000, reward=-526.00, epsilon=0.683
# Episode 77/5000, reward=-490.00, epsilon=0.680
# Episode 78/5000, reward=-419.00, epsilon=0.676
# Episode 79/5000, reward=-267.00, epsilon=0.673
# Episode 80/5000, reward=-760.00, epsilon=0.670
# Episode 81/5000, reward=-328.00, epsilon=0.666
# Episode 82/5000, reward=-314.00, epsilon=0.663
# Episode 83/5000, reward=-396.00, epsilon=0.660
# Episode 84/5000, reward=-326.00, epsilon=0.656
# Episode 85/5000, reward=-429.00, epsilon=0.653
# Episode 86/5000, reward=-346.00, epsilon=0.650
# Episode 87/5000, reward=-448.00, epsilon=0.647
# Episode 88/5000, reward=-663.00, epsilon=0.643
# Episode 89/5000, reward=-564.00, epsilon=0.640
# Episode 90/5000, reward=-331.00, epsilon=0.637
# Episode 91/5000, reward=-461.00, epsilon=0.634
# Episode 92/5000, reward=-320.00, epsilon=0.631
# Episode 93/5000, reward=-317.00, epsilon=0.627
# Episode 94/5000, reward=-426.00, epsilon=0.624
# Episode 95/5000, reward=-288.00, epsilon=0.621
# Episode 96/5000, reward=-255.00, epsilon=0.618
# Episode 97/5000, reward=-193.00, epsilon=0.615
# Episode 98/5000, reward=-212.00, epsilon=0.612
# Episode 99/5000, reward=-351.00, epsilon=0.609
# Episode 100/5000, reward=-462.00, epsilon=0.606
# Episode 101/5000, reward=-202.00, epsilon=0.603
# Episode 102/5000, reward=-245.00, epsilon=0.600
# Episode 103/5000, reward=-340.00, epsilon=0.597
# Episode 104/5000, reward=-302.00, epsilon=0.594
# Episode 105/5000, reward=-441.00, epsilon=0.591
# Episode 106/5000, reward=-297.00, epsilon=0.588
# Episode 107/5000, reward=-276.00, epsilon=0.585
# Episode 108/5000, reward=-328.00, epsilon=0.582
# Episode 109/5000, reward=-259.00, epsilon=0.579
# Episode 110/5000, reward=-320.00, epsilon=0.576
# Episode 111/5000, reward=-290.00, epsilon=0.573
# Episode 112/5000, reward=-222.00, epsilon=0.570
# Episode 113/5000, reward=-379.00, epsilon=0.568
# Episode 114/5000, reward=-339.00, epsilon=0.565
# Episode 115/5000, reward=-310.00, epsilon=0.562
# Episode 116/5000, reward=-364.00, epsilon=0.559
# Episode 117/5000, reward=-285.00, epsilon=0.556
# Episode 118/5000, reward=-209.00, epsilon=0.554
# Episode 119/5000, reward=-404.00, epsilon=0.551
# Episode 120/5000, reward=-273.00, epsilon=0.548
# Episode 121/5000, reward=-384.00, epsilon=0.545
# Episode 122/5000, reward=-292.00, epsilon=0.543
# Episode 123/5000, reward=-251.00, epsilon=0.540
# Episode 124/5000, reward=-606.00, epsilon=0.537
# Episode 125/5000, reward=-288.00, epsilon=0.534
# Episode 126/5000, reward=-413.00, epsilon=0.532
# Episode 127/5000, reward=-199.00, epsilon=0.529
# Episode 128/5000, reward=-300.00, epsilon=0.526
# Episode 129/5000, reward=-351.00, epsilon=0.524
# Episode 130/5000, reward=-175.00, epsilon=0.521
# Episode 131/5000, reward=-315.00, epsilon=0.519
# Episode 132/5000, reward=-526.00, epsilon=0.516
# Episode 133/5000, reward=-335.00, epsilon=0.513
# Episode 134/5000, reward=-308.00, epsilon=0.511
# Episode 135/5000, reward=-341.00, epsilon=0.508
# Episode 136/5000, reward=-312.00, epsilon=0.506
# Episode 137/5000, reward=-378.00, epsilon=0.503
# Episode 138/5000, reward=-299.00, epsilon=0.501
# Episode 139/5000, reward=-434.00, epsilon=0.498
# Episode 140/5000, reward=-386.00, epsilon=0.496
# Episode 141/5000, reward=-330.00, epsilon=0.493
# Episode 142/5000, reward=-290.00, epsilon=0.491
# Episode 143/5000, reward=-210.00, epsilon=0.488
# Episode 144/5000, reward=-301.00, epsilon=0.486
# Episode 145/5000, reward=-178.00, epsilon=0.483
# Episode 146/5000, reward=-331.00, epsilon=0.481
# Episode 147/5000, reward=-261.00, epsilon=0.479
# Episode 148/5000, reward=-173.00, epsilon=0.476
# Episode 149/5000, reward=-194.00, epsilon=0.474
# Episode 150/5000, reward=-268.00, epsilon=0.471
# Episode 151/5000, reward=-262.00, epsilon=0.469
# Episode 152/5000, reward=-168.00, epsilon=0.467
# Episode 153/5000, reward=-229.00, epsilon=0.464
# Episode 154/5000, reward=-243.00, epsilon=0.462
# Episode 155/5000, reward=-176.00, epsilon=0.460
# Episode 156/5000, reward=-246.00, epsilon=0.458
# Episode 157/5000, reward=-164.00, epsilon=0.455
# Episode 158/5000, reward=-164.00, epsilon=0.453
# Episode 159/5000, reward=-158.00, epsilon=0.451
# Episode 160/5000, reward=-238.00, epsilon=0.448
# Episode 161/5000, reward=-170.00, epsilon=0.446
# Episode 162/5000, reward=-173.00, epsilon=0.444
# Episode 163/5000, reward=-155.00, epsilon=0.442
# Episode 164/5000, reward=-198.00, epsilon=0.440
# Episode 165/5000, reward=-213.00, epsilon=0.437
# Episode 166/5000, reward=-161.00, epsilon=0.435
# Episode 167/5000, reward=-238.00, epsilon=0.433
# Episode 168/5000, reward=-169.00, epsilon=0.431
# Episode 169/5000, reward=-174.00, epsilon=0.429
# Episode 170/5000, reward=-226.00, epsilon=0.427
# Episode 171/5000, reward=-185.00, epsilon=0.424
# Episode 172/5000, reward=-245.00, epsilon=0.422
# Episode 173/5000, reward=-173.00, epsilon=0.420
# Episode 174/5000, reward=-211.00, epsilon=0.418
# Episode 175/5000, reward=-165.00, epsilon=0.416
# Episode 176/5000, reward=-196.00, epsilon=0.414
# Episode 177/5000, reward=-211.00, epsilon=0.412
# Episode 178/5000, reward=-197.00, epsilon=0.410
# Episode 179/5000, reward=-215.00, epsilon=0.408
# Episode 180/5000, reward=-163.00, epsilon=0.406
# Episode 181/5000, reward=-150.00, epsilon=0.404
# Episode 182/5000, reward=-166.00, epsilon=0.402
# Episode 183/5000, reward=-227.00, epsilon=0.400
# Episode 184/5000, reward=-166.00, epsilon=0.398
# Episode 185/5000, reward=-209.00, epsilon=0.396
# Episode 186/5000, reward=-265.00, epsilon=0.394
# Episode 187/5000, reward=-198.00, epsilon=0.392
# Episode 188/5000, reward=-279.00, epsilon=0.390
# Episode 189/5000, reward=-158.00, epsilon=0.388
# Episode 190/5000, reward=-166.00, epsilon=0.386
# Episode 191/5000, reward=-315.00, epsilon=0.384
# Episode 192/5000, reward=-206.00, epsilon=0.382
# Episode 193/5000, reward=-195.00, epsilon=0.380
# Episode 194/5000, reward=-261.00, epsilon=0.378
# Episode 195/5000, reward=-223.00, epsilon=0.376
# Episode 196/5000, reward=-211.00, epsilon=0.374

# %% [markdown]
# # Exercise 2: Deep Q-Learning (DQN) on LunarLander-v2
#
# ## Problem Description
# In this exercise, you will implement **Deep Q-Learning (DQN)** to solve the classic control problem **LunarLander-v2** in Gym.
#
# ### The Task
# The agent controls a lander that starts at the top of the screen and must safely land on the landing pad between two flags.
#
# - **State space**: Continuous vector of 8 variables, including:
#   - Position (x, y)
#   - Velocity (x_dot, y_dot)
#   - Angle and angular velocity
#   - Left/right leg contact indicators
# - **Action space**: Discrete, 4 actions
#   - 0: do nothing
#   - 1: fire left orientation engine
#   - 2: fire main engine
#   - 3: fire right orientation engine
# - **Rewards**:
#   - +100 to +140 for successful landing
#   - -100 for crashing
#   - Small negative reward for firing engines (fuel cost)
#   - Episode ends when lander crashes or comes to rest
#
# The goal is to train an agent that lands successfully **most of the time**.
#
# ---
#
# ## Algorithm: Deep Q-Learning
# You will implement a **DQN agent** with the following components:
#
# 1. **Q-Network**
#    - Neural network that approximates Q(s, a).
#    - Input: state vector (8 floats).
#    - Output: Q-values for 4 actions.
#    - Suggested architecture: 2 hidden layers with 128 neurons each, ReLU activation.
#
# 2. **Target Network**
#    - A copy of the Q-network that is updated less frequently (e.g., every 1000 steps).
#    - Used for stable target computation.
#
# 3. **Replay Buffer**
#    - Stores transitions `(s, a, r, s_next, done)`.
#    - Sample random mini-batches to break correlation between consecutive samples.
#
# 4. **ε-Greedy Policy**
#    - With probability ε, take a random action.
#    - Otherwise, take `argmax_a Q(s, a)`.
#    - Decay ε over time (e.g., from 1.0 → 0.05).
#
# 5. **Q-Learning Method**
#
#
#
# **Final note:**
#    No code base is necessary. At this point, you must know how to implement evertything.
#    For reference, but not recommended ([Here](https://colab.research.google.com/drive/1Gl0kuln79A__hgf2a-_-mwoGISXQDK_X?authuser=1#scrollTo=8Sd0q9DG8Rt8&line=56&uniqifier=1) is a solution)
#
# ---
# ## Deliverables
# 1. **Code**:
# - Q-network (PyTorch).
# - Training loop with ε-greedy policy, target network, and Adam optimizer.
#
# 2. **Plots**:
# - Episode returns vs training episodes.
# - Evaluation performance with a greedy policy (ε = 0).
#
# 3. **Short Write-up (≤1 page)**:
# - Did your agent learn to land consistently?
# - How many episodes did it take before you saw improvement?
# - What effect did replay buffer size, target update frequency, and learning rate have on stability?
# - Compare results across different runs (does it sometimes fail to converge?).
#
# Compare this task with the **MountainCar-v0** problem you solved earlier:
# - What is **extra** or more challenging in LunarLander?
# - Consider state dimensionality, number of actions, reward shaping, and the difficulty of exploration.
# - Why might DQN be necessary here, whereas simpler methods (like tile coding) could work for MountainCar?

# %%
env = gym.make("LunarLander-v2")
state_dim = env.observation_space.shape[0]   # 8
n_actions = env.action_space.n         # 4

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
alpha = 1e-3
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.995
replay_buffer_size = 100000
batch_size = 64
target_update_freq = 1000
num_episodes = 500


class QNetwork(nn.Module):
    def __init__(self, state_dim, n_actions):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )

    def forward(self, x):
        return self.net(x)

q_net = QNetwork(state_dim, n_actions).to(device)
target_net = QNetwork(state_dim, n_actions).to(device)
target_net.load_state_dict(q_net.state_dict())
target_net.eval()

optimizer = optim.Adam(q_net.parameters(), lr=alpha)
loss_fn = nn.MSELoss()

replay_buffer = deque(maxlen=replay_buffer_size)

# %%
rewards_dqn = []
step_count = 0

for episode in range(num_episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = epsilon_greedy(state, epsilon)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        total_reward += reward


        replay_buffer.append((state, action, reward, next_state, done))
        state = next_state
        step_count += 1

        if len(replay_buffer) >= batch_size:
            batch = random.sample(replay_buffer, batch_size)
            states, actions, rewards, next_states, dones = zip(*batch)

            states = torch.tensor(states, dtype=torch.float32, device=device)
            actions = torch.tensor(actions, dtype=torch.long, device=device).unsqueeze(1)
            rewards = torch.tensor(rewards, dtype=torch.float32, device=device).unsqueeze(1)
            next_states = torch.tensor(next_states, dtype=torch.float32, device=device)
            dones = torch.tensor(dones, dtype=torch.float32, device=device).unsqueeze(1)

            q_values = q_net(states).gather(1, actions)

            with torch.no_grad():
                next_q_values = target_net(next_states).max(1, keepdim=True)[0]
                target_q = rewards + gamma * next_q_values * (1 - dones)
            loss = loss_fn(q_values, target_q)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        if step_count % target_update_freq == 0:
            target_net.load_state_dict(q_net.state_dict())

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    rewards_dqn.append(total_reward)
    print(f"Episode {episode+1}/{num_episodes}, Reward={total_reward:.1f}, Epsilon={epsilon:.3f}")

plt.plot(rewards_dqn)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("DQN on LunarLander-v2")
plt.grid()
plt.show()
